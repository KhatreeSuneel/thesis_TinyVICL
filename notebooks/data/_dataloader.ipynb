# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import pandas as pd

import src.data.dataloader as dataloader
import src.utils.utils as utils

# %%
utils.setup_logging()

# Set current working directory to root
os.chdir("../..")
print(f"Set current working directory to '{os.getcwd()}' ...")

# Load config yaml file
CFG: dict = utils.load_config("configs/config.yaml")

# %%
# %%time

# Get metadata df
dataloader.load_data(CFG)
df = pd.read_csv(CFG["dataloader"]["metadata_location"], index_col=0)

# %%
df.head(10)

# %%
os.chdir(Path.cwd().parent)

# %%
import sys
from pathlib import Path

# Go up 3 levels from the current notebook directory to reach project root
project_root = Path.cwd().resolve().parents[1]
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

# %%
project_root

# %%
import os
import pandas as pd

import src.data.dataloader as dataloader
import src.utils.utils as utils

# %%
utils.setup_logging()

# Set current working directory to root
os.chdir("../..")
print(f"Set current working directory to '{os.getcwd()}' ...")

# Load config yaml file
CFG: dict = utils.load_config("configs/new_config.yaml")

# %%
# %%time

# Get metadata df
dataloader.load_data(CFG)
df = pd.read_csv(CFG["dataloader"]["metadata_location"])

# %%
df.head(10)
